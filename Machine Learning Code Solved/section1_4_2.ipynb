# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('Insights.csv')

# %%
data.fillna(0,inplace=True)

# %%
data
# Out:
#            Date   HS Code                                            Product  \
# 0     31-Jan-20  42022110  LADIES LEATHER HAND BAG 100% COW LEATHER SAC C...
# 1     31-Jan-20  42022110                                                BAG
# 2     28-Jan-20  42022110           COW NAPPA LEATHER HAND BAG ORDER NO.2167
# 3     28-Jan-20  42022110           COW NAPPA LEATHER HAND BAG ORDER NO.2213
# 4     28-Jan-20  42022110           COW NAPPA LEATHER HAND BAG ORDER NO.1132
# ...         ...       ...                                                ...
# 4968  24-Oct-19  42022220  COTTON CLUTCH BAGS(80% COTTON 10% GLASS BEAD 1...
# 4969  24-Oct-19  42022220  COTTON CLUTCH BAGS(80% COTTON 10% GLASS BEAD 1...
# 4970  24-Oct-19  42022220  COTTON TABLET BAGS(80%COTTON 10%ACCORD 1 0%GLA...
# 4971  24-Oct-19  42022220                  100% COTTON P/L BLOCK PRINTED BAG
# 4972  24-Oct-19  42022220  COTTON SHOPPING BAGS(80% COTTON 10% GLA SS BEA...
#
#      Specific Product Port of Origin Country of Destination  \
# 0             Leather           JNPT                 France
# 1             Leather           JNPT                  Japan
# 2             Leather           JNPT                  Spain
# 3             Leather           JNPT                  Spain
# 4             Leather           JNPT                  Spain
# ...               ...            ...                    ...
# 4968           Cotton           JNPT              Mauritius
# 4969           Cotton           JNPT              Mauritius
# 4970           Cotton           JNPT              Mauritius
# 4971           Cotton           JNPT                Denmark
# 4972           Cotton           JNPT              Mauritius
#
#      Port of Destination  Value(USD)  Std Qty Std Unit  Std Unit Price(USD)  \
# 0               Le Havre     1543.70     86.0      NOS                17.95
# 1                   Kobe     3074.75    710.0      NOS                 4.33
# 2              Algeciras     2487.49    100.0      NOS                24.87
# 3              Algeciras     1529.66    100.0      NOS                15.30
# 4              Algeciras     2558.97     70.0      NOS                36.56
# ...                  ...         ...      ...      ...                  ...
# 4968               Louis      117.00     18.0      NOS                 6.50
# 4969               Louis       78.00     12.0      NOS                 6.50
# 4970               Louis       90.00     12.0      NOS                 7.50
# 4971              Aarhus     8792.80   3032.0      NOS                 2.90
# 4972               Louis      114.00     12.0      NOS                 9.50
#
#          Qty Unit  Value In FC  Unit Rate In FC Unit Rate Currency  \
# 0       86.0  PCS       1543.7            17.95                USD
# 1      710.0  PCS       3074.3             4.33                USD
# 2      100.0  PCS       2365.0            23.65                EUR
# 3      100.0  PCS       1450.0            14.50                EUR
# 4       70.0  PCS       2436.0            34.80                EUR
# ...      ...  ...          ...              ...                ...
# 4968    18.0  PCS        117.0             6.50                USD
# 4969    12.0  PCS        114.0             9.50                USD
# 4970    12.0  PCS        114.0             9.50                USD
# 4971  3032.0  PCS       8792.8             2.90                USD
# 4972    12.0  PCS        114.0             9.50                USD
#
#       Value(INR) Shipment Mode  Invoice Value INR
# 0      107981.82           Sea                0.0
# 1      215078.96           Sea                0.0
# 2      174000.00           Sea                0.0
# 3      107000.00           Sea                0.0
# 4      179000.00           Sea                0.0
# ...          ...           ...                ...
# 4968     8260.21           Sea                0.0
# 4969     5506.82           Sea                0.0
# 4970     6354.00           Sea                0.0
# 4971   620771.84           Sea                0.0
# 4972     8048.41           Sea                0.0
#
# [4973 rows x 19 columns]

# %%
df_filtered = data

# %%
currency = df_filtered["Unit Rate Currency"].unique()
currency = currency.tolist()
df_filtered['Unit Rate Currency'] = df_filtered['Unit Rate Currency'].map(lambda x: currency.index(x))

spProd = df_filtered["Specific Product"].unique()
spProd = spProd.tolist()
df_filtered['Specific Product'] = df_filtered['Specific Product'].map(lambda x: spProd.index(x))

# df_filtered['Qty'] = df_filtered['Qty'].map(lambda x: 0 if x <100 else 1)
shipment = df_filtered["Shipment Mode"].unique()
shipment = shipment.tolist()
df_filtered['Shipment Mode'] = df_filtered['Shipment Mode'].map(lambda x: shipment.index(x))
prod = df_filtered["Product"].unique()
prod = prod.tolist()
df_filtered['Product'] = df_filtered['Product'].map(lambda x: prod.index(x))
df_filtered
# Out:
#            Date   HS Code  Product  Specific Product Port of Origin  \
# 0     31-Jan-20  42022110        0                 0           JNPT
# 1     31-Jan-20  42022110        1                 0           JNPT
# 2     28-Jan-20  42022110        2                 0           JNPT
# 3     28-Jan-20  42022110        3                 0           JNPT
# 4     28-Jan-20  42022110        4                 0           JNPT
# ...         ...       ...      ...               ...            ...
# 4968  24-Oct-19  42022220     3810                 5           JNPT
# 4969  24-Oct-19  42022220     3811                 5           JNPT
# 4970  24-Oct-19  42022220     3812                 5           JNPT
# 4971  24-Oct-19  42022220     3813                 5           JNPT
# 4972  24-Oct-19  42022220     3814                 5           JNPT
#
#      Country of Destination Port of Destination  Value(USD)  Std Qty Std Unit  \
# 0                    France            Le Havre     1543.70     86.0      NOS
# 1                     Japan                Kobe     3074.75    710.0      NOS
# 2                     Spain           Algeciras     2487.49    100.0      NOS
# 3                     Spain           Algeciras     1529.66    100.0      NOS
# 4                     Spain           Algeciras     2558.97     70.0      NOS
# ...                     ...                 ...         ...      ...      ...
# 4968              Mauritius               Louis      117.00     18.0      NOS
# 4969              Mauritius               Louis       78.00     12.0      NOS
# 4970              Mauritius               Louis       90.00     12.0      NOS
# 4971                Denmark              Aarhus     8792.80   3032.0      NOS
# 4972              Mauritius               Louis      114.00     12.0      NOS
#
#       Std Unit Price(USD)     Qty Unit  Value In FC  Unit Rate In FC  \
# 0                   17.95    86.0  PCS       1543.7            17.95
# 1                    4.33   710.0  PCS       3074.3             4.33
# 2                   24.87   100.0  PCS       2365.0            23.65
# 3                   15.30   100.0  PCS       1450.0            14.50
# 4                   36.56    70.0  PCS       2436.0            34.80
# ...                   ...     ...  ...          ...              ...
# 4968                 6.50    18.0  PCS        117.0             6.50
# 4969                 6.50    12.0  PCS        114.0             9.50
# 4970                 7.50    12.0  PCS        114.0             9.50
# 4971                 2.90  3032.0  PCS       8792.8             2.90
# 4972                 9.50    12.0  PCS        114.0             9.50
#
#       Unit Rate Currency  Value(INR)  Shipment Mode  Invoice Value INR
# 0                      0   107981.82              0                0.0
# 1                      0   215078.96              0                0.0
# 2                      1   174000.00              0                0.0
# 3                      1   107000.00              0                0.0
# 4                      1   179000.00              0                0.0
# ...                  ...         ...            ...                ...
# 4968                   0     8260.21              0                0.0
# 4969                   0     5506.82              0                0.0
# 4970                   0     6354.00              0                0.0
# 4971                   0   620771.84              0                0.0
# 4972                   0     8048.41              0                0.0
#
# [4973 rows x 19 columns]

# %%
print(spProd)
# Out:
# ['Leather', 'Nylon', 'PU', 'Others', 'Polyester', 'Cotton']

# %%
plt.scatter(data['Specific Product'],data['Value(INR)'])
# plt.xlim(-180,180)
# plt.ylim(-90,90)
plt.show()

# %%
x = data.iloc[:,11:17]
# x = x.drop(['Unit',"Value In FC","Unit Rate In FC","Unit Rate Currency"],axis=1)
x
# Out:
#          Qty Unit  Value In FC  Unit Rate In FC  Unit Rate Currency  \
# 0       86.0  PCS       1543.7            17.95                   0
# 1      710.0  PCS       3074.3             4.33                   0
# 2      100.0  PCS       2365.0            23.65                   1
# 3      100.0  PCS       1450.0            14.50                   1
# 4       70.0  PCS       2436.0            34.80                   1
# ...      ...  ...          ...              ...                 ...
# 4968    18.0  PCS        117.0             6.50                   0
# 4969    12.0  PCS        114.0             9.50                   0
# 4970    12.0  PCS        114.0             9.50                   0
# 4971  3032.0  PCS       8792.8             2.90                   0
# 4972    12.0  PCS        114.0             9.50                   0
#
#       Value(INR)
# 0      107981.82
# 1      215078.96
# 2      174000.00
# 3      107000.00
# 4      179000.00
# ...          ...
# 4968     8260.21
# 4969     5506.82
# 4970     6354.00
# 4971   620771.84
# 4972     8048.41
#
# [4973 rows x 6 columns]

# %%
x["Specific Product"] = df_filtered["Specific Product"]
x = x.drop(['Unit'],axis=1)
x
# Out:
#          Qty  Value In FC  Unit Rate In FC  Unit Rate Currency  Value(INR)  \
# 0       86.0       1543.7            17.95                   0   107981.82
# 1      710.0       3074.3             4.33                   0   215078.96
# 2      100.0       2365.0            23.65                   1   174000.00
# 3      100.0       1450.0            14.50                   1   107000.00
# 4       70.0       2436.0            34.80                   1   179000.00
# ...      ...          ...              ...                 ...         ...
# 4968    18.0        117.0             6.50                   0     8260.21
# 4969    12.0        114.0             9.50                   0     5506.82
# 4970    12.0        114.0             9.50                   0     6354.00
# 4971  3032.0       8792.8             2.90                   0   620771.84
# 4972    12.0        114.0             9.50                   0     8048.41
#
#       Specific Product
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 4968                 5
# 4969                 5
# 4970                 5
# 4971                 5
# 4972                 5
#
# [4973 rows x 6 columns]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(4)
kmeans.fit(x.astype(np.float32))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([0, 0, 0, ..., 0, 3, 0])

# %%
data_with_clusters = df_filtered.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#            Date   HS Code  Product  Specific Product Port of Origin  \
# 0     31-Jan-20  42022110        0                 0           JNPT
# 1     31-Jan-20  42022110        1                 0           JNPT
# 2     28-Jan-20  42022110        2                 0           JNPT
# 3     28-Jan-20  42022110        3                 0           JNPT
# 4     28-Jan-20  42022110        4                 0           JNPT
# ...         ...       ...      ...               ...            ...
# 4968  24-Oct-19  42022220     3810                 5           JNPT
# 4969  24-Oct-19  42022220     3811                 5           JNPT
# 4970  24-Oct-19  42022220     3812                 5           JNPT
# 4971  24-Oct-19  42022220     3813                 5           JNPT
# 4972  24-Oct-19  42022220     3814                 5           JNPT
#
#      Country of Destination Port of Destination  Value(USD)  Std Qty Std Unit  \
# 0                    France            Le Havre     1543.70     86.0      NOS
# 1                     Japan                Kobe     3074.75    710.0      NOS
# 2                     Spain           Algeciras     2487.49    100.0      NOS
# 3                     Spain           Algeciras     1529.66    100.0      NOS
# 4                     Spain           Algeciras     2558.97     70.0      NOS
# ...                     ...                 ...         ...      ...      ...
# 4968              Mauritius               Louis      117.00     18.0      NOS
# 4969              Mauritius               Louis       78.00     12.0      NOS
# 4970              Mauritius               Louis       90.00     12.0      NOS
# 4971                Denmark              Aarhus     8792.80   3032.0      NOS
# 4972              Mauritius               Louis      114.00     12.0      NOS
#
#       Std Unit Price(USD)     Qty Unit  Value In FC  Unit Rate In FC  \
# 0                   17.95    86.0  PCS       1543.7            17.95
# 1                    4.33   710.0  PCS       3074.3             4.33
# 2                   24.87   100.0  PCS       2365.0            23.65
# 3                   15.30   100.0  PCS       1450.0            14.50
# 4                   36.56    70.0  PCS       2436.0            34.80
# ...                   ...     ...  ...          ...              ...
# 4968                 6.50    18.0  PCS        117.0             6.50
# 4969                 6.50    12.0  PCS        114.0             9.50
# 4970                 7.50    12.0  PCS        114.0             9.50
# 4971                 2.90  3032.0  PCS       8792.8             2.90
# 4972                 9.50    12.0  PCS        114.0             9.50
#
#       Unit Rate Currency  Value(INR)  Shipment Mode  Invoice Value INR  \
# 0                      0   107981.82              0                0.0
# 1                      0   215078.96              0                0.0
# 2                      1   174000.00              0                0.0
# 3                      1   107000.00              0                0.0
# 4                      1   179000.00              0                0.0
# ...                  ...         ...            ...                ...
# 4968                   0     8260.21              0                0.0
# 4969                   0     5506.82              0                0.0
# 4970                   0     6354.00              0                0.0
# 4971                   0   620771.84              0                0.0
# 4972                   0     8048.41              0                0.0
#
#       Cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 4968        0
# 4969        0
# 4970        0
# 4971        3
# 4972        0
#
# [4973 rows x 20 columns]

# %%
plt.scatter(data_with_clusters['Specific Product'],data_with_clusters['Value(INR)'],c=data_with_clusters['Cluster'],cmap='rainbow')
# plt.xlim(-180,180)
# plt.ylim(-90,90)
plt.show()

# %%
wcss=[]
for i in range(1,10):
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
wcss
# Out:
# [2715186199279401.0,
#  976259780640494.8,
#  516372228930603.7,
#  305317748540599.8,
#  202212921333261.22,
#  134061280907824.16,
#  103253780835360.75,
#  76825121129324.61,
#  58832537396221.28]

# %%
number_cluster = range(1,10)
plt.plot(number_cluster,wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')
